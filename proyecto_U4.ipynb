# %% [markdown]
# <a href="https://colab.research.google.com/github/dany-tomlinson28/UNIDAD.4/blob/main/proyecto_U4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Introducción**
#
# Según el INEGI (2020) el 4.9% de la población en México de 15 años o mas no cuenta con educacion, el 49.3% tiene educación básica, y solo el 21.6% cuenta con educación superior.
#
# ![Captura de pantalla 2024-12-08 090851.png](data:image/png;base64,...)
#
#
# Durante mucho tiempo, el sistema educativo en México ha inclinado su valoración hacia los estudiantes con mayores calificación obtenidas, asumiendo que obtener un puntaje perfecto de 100 es sinónimo de inteligencia y preparación. Sin embargo, este enfoque simplista ignora una realidad compleja: las calificaciones de los estudiantes están influenciadas por una variedad de factores cualitativos que van más allá de los conocimientos académicos. Aspectos como el entorno familiar, las condiciones socioeconómicas, el estado emocional, juegan un papel crucial en el desempeño escolar.
#
# Dado este panorama, surge la necesidad de analizar con mayor profundidad qué factores afectan las calificaciones de los estudiantes y cómo estos interactúan. Este proyecto tiene como objetivo realizar un diseño experimental que permita identificar y cuantificar la influencia de un factor específico en el rendimiento académico. A través de este enfoque, se busca generar una comprensión más integral del proceso educativo, contribuyendo al diseño de estrategias que promuevan un aprendizaje más equitativo y efectivo.

# %% [markdown]
# **Marco teórico**
#
# *Prueba ANOVA*
#
# En estadística, el análisis de la varianza, también llamado ANOVA (del inglés Analysis of Variance), es una técnica que permite comparar las varianzas entre las medias de diferentes muestras.
#
# El análisis de la varianza (ANOVA) sirve para analizar si existe alguna diferencia entre las medias de más de dos poblaciones. De manera que el análisis de la varianza permite determinar si las medias poblacionales de dos o más grupos son diferentes analizando la variabilidad entre las medias de las muestras. Por lo tanto, la hipótesis nula del análisis de la varianza es que las medias de todos los grupos analizados son iguales. Mientras que la hipótesis alternativa sostiene que al menos una de las medias es diferente.
#
# *Prueba Tukey*
#
# La prueba de Tukey es un método que tiene como fin comparar las medias individuales provenientes de un análisis de varianza de varias muestras sometidas a tratamientos distintos.
# El test, presentado en el año 1949 por John.W. Tukey, permite discernir si los resultados obtenidos son significativamente diferentes o no.  le conoce también como la prueba de diferencia honestamente significativa de Tukey (Tukey’s HSD test por sus siglas en inglés). En los experimentos donde se compara entre tres o más tratamientos diferentes aplicados a igual número de muestras, se requiere discernir si los resultados son significativamente distintos o no.
#
# *Valor p*
#
# El valor p (o p-valor) es la probabilidad de haber obtenido un estadístico de prueba suponiendo que la hipótesis nula es cierta. Es decir, el valor p es un valor entre 0 y 1 que se usa en el contraste de hipótesis para rechazar o aceptar la hipótesis nula. Concretamente, la hipótesis nula se rechaza si el valor p es menor que el nivel de significancia. Por otro lado, si el valor p es mayor que el nivel de significancia, se acepta la hipótesis nula y se rechaza la hipótesis alternativa.
#
# *Rendimiento academico*
#
# El rendimiento académico es un cambio en términos de destrezas o habilidades conductuales que pueden aumentar con el tiempo y no es causado por un proceso de crecimiento, sino por una evolución de aprendizaje. La materialización de los resultados del proceso de aprendizaje puede ser en forma de soluciones orales o escritas, y las habilidades y la resolución de problemas pueden medirse o evaluarse directamente mediante pruebas estandarizadas.
#
# *Factores cualitativos a experimentar*
#
# * Participacion parental:	Nivel de participación de los padres en la educaciónn del estudiante (Baja, Media, Alta).
# * Acceso a recursos: Disponibilidad de recursos educativos (Bajo, Medio, Alto).
# * Actividades extracurriculares: Participación en actividades extracurriculares (Sí, No).
# * Nivel motivacion:	Nivel de motivación del estudiante (Bajo, Medio, Alto).
# * Acceso internet:	Disponibilidad de acceso a internet (Sí, No).
# * Ingreso familiar:	Nivel de ingresos familiares (Bajo, Medio, Alto).
# * Calidad profesorado:	Calidad de los profesores (Baja, Media, Alta).
# * Tipo escuela:	Tipo de escuela asistida (Pública, Privada).
# * Influencia companieros:	Influencia de los compañeros en el rendimiento académico (Positiva, Neutral, Negativa).
# * Discapacidad aprendizaje:	Presencia de discapacidades de aprendizaje (Sí, No).
# * Nivel estudios padres:	Nivel educativo más alto de los padres (Preparatoria, Universidad, Posgrado).
# * Distancia:	Distancia desde el hogar a la escuela (Cerca, Moderada, Lejos).
# * Genero:	Género del estudiante (Masculino, Femenino).

# %% [markdown]
# **Metodologia**
#
# En el presente proyecto se busca analizar cuales son los factores cualititativos que afectan en el rendimineto academico de los estudiantes, la unica variable cuantitavia que será tomada en cuenta es el puntaje en el examen que los estudiantes hayan obtenido, se utilizarán dos tipos de pruebas para lograr lla¿evar a caboo la investigación.
#
# *Prueba ANOVA:* Será utilizada para analizar la variable cualitativa de interés con la variable cuantitativa (puntaje en el examen) y saber si existen diferencias significativas entre los grupos.
#
# *Prueba Tukey:* Esta prueba ayudará a observar cuales son los grupos que cuentan con la diferencia significativa mencionada por ANOVA.

# %% [markdown]
# **Resultados**

# %%
import pandas as pd
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dany-tomlinson28/UNIDAD.4/refs/heads/main/dataset%20(1).csv')
df.drop(columns=[], inplace=True)
df.dropna(inplace=True)
df
# Out:
#       horas_estudio  asistencia participacion_parental acceso_a_recursos  \
# 0                23          84                   bajo           elevado
# 1                19          64                   bajo             medio
# 2                24          98                  medio              bajo
# 3                29          89                   bajo             medio
# 4                19          92                  medio              bajo
# ...             ...         ...                    ...               ...
# 6602             25          69                elevado             medio
# 6603             23          76                elevado             medio
# 6604             20          90                  medio              bajo
# 6605             10          86                elevado           elevado
# 6606             15          67                  medio              bajo
#
#      actividades_extracurriculares  horas_suenio  calificaciones_previas  \
# ...

# %% [markdown]
# **Participación Parental**

# %%
df['participacion_parental'].unique()
# Out:
# array(['bajo', 'medio', 'elevado'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['participacion_parental'] == 'bajo']['puntaje_examen'],
    df[df['participacion_parental'] == 'medio']['puntaje_examen'],
    df[df['participacion_parental'] == 'elevado']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue: }\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 80.46
# Valor p:  3.086484723306131e-35
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['participacion_parental'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
#    bajo elevado   1.7334   0.0  1.4042  2.0626   True
#    bajo   medio   0.7344   0.0  0.4363  1.0326   True
# elevado   medio   -0.999   0.0 -1.2636 -0.7344   True
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# Como se puede observar, se realizó un análisis con la variable cualitativa de participación parental y sus niveles (elevado, medio y bajo), y la variable cuantitativa de puntaje en el examen. La prueba ANOVA dio a conocer que existen diferencias significativas entre al menos dos tratamientos, lo que se comprueba con la prueba Tukey, ya que esta arroja que las diferencias significativas son en todos los grupos. El gráfico muestra que, mientras más elevada es la participación parental en la educación de los estudiantes, su puntaje también es mayor. Es por eso que se les recomienda a los padres ser más participativos en la educación de sus hijos.

# %% [markdown]
# **Acceso a recursos**

# %%
df['acceso_a_recursos'].unique()
# Out:
# array(['elevado', 'medio', 'bajo'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['acceso_a_recursos'] == 'bajo']['puntaje_examen'],
    df[df['acceso_a_recursos'] == 'medio']['puntaje_examen'],
    df[df['acceso_a_recursos'] == 'elevado']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 77.74
# Valor p: 4.409839909861347e-34
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['acceso_a_recursos'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2 meandiff p-adj  lower   upper  reject
# -----------------------------------------------------
#    bajo elevado   1.4212   0.0  1.1539  1.6885   True
#    bajo   medio   0.6001   0.0  0.3157  0.8845   True
# elevado   medio  -0.8211   0.0 -1.1309 -0.5113   True
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# En este caso, la variable cualitativa a analizar es "acceso a recursos", con los niveles (elevado, medio, bajo). Como era de esperarse, la tabla ANOVA muestra diferencias significativas en los tratamientos. Después de obtener este resultado, se realiza la prueba Tukey, que en la tabla da a conocer que los tres grupos tienen diferencias significativas. Una observación interesante es que, al igual que en el análisis anterior, mientras más elevado es el acceso a recursos, el promedio de los estudiantes también es mayor. Es decir, el acceso a recursos educativos sí influye en las calificaciones de los alumnos.

# %% [markdown]
# **Actividades extracurriculares**

# %%
df['actividades_extracurriculares'].unique()
# Out:
# array(['no', 'si'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['actividades_extracurriculares'] == 'no']['puntaje_examen'],
    df[df['actividades_extracurriculares'] == 'si']['puntaje_examen'],

)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 25.46
# Valor p: 4.6465544032283915e-07
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['actividades_extracurriculares'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     no     si   0.5032   0.0 0.3077 0.6987   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# Después de realizar la prueba ANOVA y la prueba Tukey con la variable cualitativa de "Actividades extracurriculares", cuyos grupos son solo "sí" y "no", se obtuvo que sí existe una diferencia significativa entre ambos grupos. La prueba Tukey realizada dio como resultado que los estudiantes que no realizan actividades extracurriculares tienen calificaciones menores. Por lo cual, se recomienda realizar este tipo de actividades, ya que pueden ayudar a ejercitar la mente o motivar a los estudiantes.

# %% [markdown]
# **Nivel de motivación**

# %%
df['nivel_motivacion'].unique()
# Out:
# array(['bajo', 'medio', 'elevado'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['nivel_motivacion'] == 'bajo']['puntaje_examen'],
    df[df['nivel_motivacion'] == 'medio']['puntaje_examen'],
    df[df['nivel_motivacion'] == 'elevado']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 25.54
# Valor p: 9.000204034394693e-12
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['nivel_motivacion'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2 meandiff p-adj   lower  upper  reject
# -----------------------------------------------------
#    bajo elevado   0.9794    0.0  0.6474 1.3115   True
#    bajo   medio   0.5744    0.0  0.3086 0.8402   True
# elevado   medio   -0.405 0.0048 -0.7071 -0.103   True
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# El nivel de motivación fue la siguiente variable que se puso a prueba, con tres grupos obtenidos (elevado, medio, bajo). La prueba ANOVA dio como resultado una diferencia significativa, lo que se comprueba con Tukey, ya que, como era esperado, los estudiantes con menor motivación tienden a tener las calificaciones más bajas. Por esta razón, se recomienda buscar actividades que ayuden a elevar la motivación de los estudiantes.

# %% [markdown]
# **Acceso a internet**

# %%
df['acceso_internet'].unique()
# Out:
# array(['si', 'no'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['acceso_internet'] == 'si']['puntaje_examen'],
    df[df['acceso_internet'] == 'no']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 16.71
# Valor p: 4.4128283860948813e-05
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['acceso_internet'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     no     si   0.7549   0.0 0.3929 1.1169   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# Después de realizar la prueba ANOVA y la prueba Tukey con la variable cualitativa de "Acceso a internet", cuyos grupos son solo "sí" y "no", se obtuvo que sí existe una diferencia significativa entre ambos grupos. La prueba Tukey realizada dio como resultado que los estudiantes que no cuentan con acceso a internet tienen calificaciones más bajas, lo cual tiene sentido, pues en la actualidad el internet se ha convertido en algo indispensable.

# %% [markdown]
# **Ingreso familiar**

# %%
df['ingreso_familiar'].unique()
# Out:
# array(['bajo', 'medio', 'elevado'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['ingreso_familiar'] == 'bajo']['puntaje_examen'],
    df[df['ingreso_familiar'] == 'medio']['puntaje_examen'],
    df[df['ingreso_familiar'] == 'elevado']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 28.78
# Valor p: 3.59767227814745e-13
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['ingreso_familiar'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#    bajo elevado   0.9882    0.0  0.6717  1.3048   True
#    bajo   medio   0.5178    0.0  0.2631  0.7725   True
# elevado   medio  -0.4705 0.0015 -0.7873 -0.1536   True
# ------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# En este caso, la variable cualitativa a analizar es "ingreso familiar", con los niveles (elevado, medio, bajo). La prueba ANOVA muestra diferencias significativas en los tratamientos. Después de obtener este resultado, se realiza la prueba Tukey, que en la tabla da a conocer que los tres grupos tienen diferencias significativas. Además, mientras más elevado es el ingreso familiar, el promedio de los estudiantes también es mayor. Podemos ligar esto a las variables ya analizadas, es decir, si el nivel de ingresos es bajo, el acceso a internet, a recursos o las actividades extracurriculares se vuelven un lujo que no es posible costear.

# %% [markdown]
# **Calidad de profesorado**

# %%
df['calidad_profesorado'].unique()
# Out:
# array(['medio', 'bajo', 'elevado'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['calidad_profesorado'] == 'bajo']['puntaje_examen'],
    df[df['calidad_profesorado'] == 'medio']['puntaje_examen'],
    df[df['calidad_profesorado'] == 'elevado']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 17.12
# Valor p: 3.844782377251745e-08
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['calidad_profesorado'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#    bajo elevado   0.5447    0.0  0.2585  0.8309   True
#    bajo   medio  -0.1345 0.4821 -0.4082  0.1392  False
# elevado   medio  -0.6792    0.0 -0.9638 -0.3947   True
# ------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# Como se puede observar, se realizó un análisis con la variable cualitativa de "Calidad del profesorado" y sus niveles (elevado, medio y bajo), y la variable cuantitativa de puntaje en el examen. La prueba ANOVA dio a conocer que existen diferencias significativas entre al menos dos tratamientos, lo que se comprueba con la prueba Tukey, ya que esta arroja que las diferencias significativas son en todos los grupos. El gráfico muestra que, mientras más elevada es la calidad de los profesores en la educación de los estudiantes, su puntaje también es mayor. Esto es entendible, ya que el profesor es el encargado de transmitir sus conocimientos a los alumnos y, si esto no se realiza de manera correcta, los conocimientos del alumno no serán suficientes para obtener una buena calificación.

# %% [markdown]
# **Tipo de escuela**

# %%
df['tipo_escuela'].unique()
# Out:
# array(['publico', 'privado'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['tipo_escuela'] == 'publico']['puntaje_examen'],
    df[df['tipo_escuela'] == 'privado']['puntaje_examen'],

)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 0.75
# Valor p: 0.3854987810260675
#
# Conclusión: No hay diferencias significativas entre los tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['tipo_escuela'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2 meandiff p-adj   lower  upper  reject
# -----------------------------------------------------
# privado publico  -0.0924 0.3855 -0.3011 0.1163  False
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# En la variable cualitativa "Tipo de escuela", con los grupos de privada y pública, se realizan la prueba ANOVA y la prueba Tukey. La primera indica que no hay una diferencia significativa entre los grupos, y la segunda ayuda a observar que, aunque los tipos de escuelas sí tienen diferencias, estas no son completamente opuestas. Es decir, una escuela pública puede tener calificaciones altas o bajas, al igual que una privada.

# %% [markdown]
# **Influencia de compañeros**

# %%
df['influencia_companieros'].unique()
# Out:
# array(['positivo', 'negativo', 'neutral'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['influencia_companieros'] == 'positivo']['puntaje_examen'],
    df[df['influencia_companieros'] == 'negativo']['puntaje_examen'],
    df[df['influencia_companieros'] == 'neutral']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 32.18
# Valor p: 1.2426130744876118e-14
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['influencia_companieros'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1   group2  meandiff p-adj  lower  upper  reject
# ------------------------------------------------------
# negativo  neutral   0.6329    0.0 0.3229 0.9429   True
# negativo positivo   1.0538    0.0  0.745 1.3626   True
#  neutral positivo   0.4209 0.0004 0.1638 0.6779   True
# ------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# La influencia de los compañeros fue la siguiente variable que se puso a prueba, con tres grupos obtenidos (positivo, neutral, bajo). La prueba ANOVA dio como resultado una diferencia significativa, lo que se comprueba con Tukey. Según esta prueba, los estudiantes que tienen una influencia negativa suelen tener calificaciones bajas.

# %% [markdown]
# **Discapacidad de aprendizaje**

# %%
df['discapacidad_aprendizaje'].unique()
# Out:
# array(['no', 'si'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['discapacidad_aprendizaje'] == 'no']['puntaje_examen'],
    df[df['discapacidad_aprendizaje'] == 'si']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 45.21
# Valor p: 1.9211255816201963e-11
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['discapacidad_aprendizaje'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#     no     si  -1.0725   0.0 -1.3852 -0.7598   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# Al someter a la variable cualitativa de "Discapacidad de aprendizaje" a la prueba ANOVA y Tukey, se obtuvo que claramente sí hay una diferencia entre los alumnos que sí tienen una discapacidad de aprendizaje y los que no. Es por eso que en el gráfico obtenido se muestra que los alumnos con discapacidades tienen un comportamiento diferente en comparación con aquellos que no tienen ninguna.

# %% [markdown]
# **Nivel de estudio de los padres**

# %%
df['nivel_estudio_padres'].unique()
# Out:
# array(['preparatoria', 'universidad', 'posgrado'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['nivel_estudio_padres'] == 'preparatoria']['puntaje_examen'],
    df[df['nivel_estudio_padres'] == 'univesidad']['puntaje_examen'],
    df[df['nivel_estudio_padres'] == 'posgrado']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: nan
# Valor p: nan
#
# Conclusión: No hay diferencias significativas entre los tratamientos.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:4102: DegenerateDataWarning: at least one input has length 0
#   if _f_oneway_is_too_small(samples):

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['nivel_estudio_padres'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#    group1       group2    meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------------
#     posgrado preparatoria  -1.0778    0.0 -1.3801 -0.7754   True
#     posgrado  universidad  -0.6142    0.0 -0.9429 -0.2856   True
# preparatoria  universidad   0.4635 0.0001  0.2002  0.7268   True
# ----------------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# El nivel de estudio de los padres de los estudiantes también se sometió a las pruebas ANOVA y Tukey. La primera prueba nos abrió el panorama al arrojar que sí hay una diferencia significativa entre los grupos de posgrado, universidad y preparatoria. La prueba Tukey confirmó el resultado ya mencionado, dando a conocer que, mientras el nivel de educación de los padres es más elevado, las calificaciones de los alumnos también serán más altas. Este factor puede influir en la motivación de los alumnos, así como en la presencia parental y en el nivel de ingresos por familia.

# %% [markdown]
# **Distancia del hogar a la escuela**

# %%
df['distancia'].unique()
# Out:
# array(['cercano', 'moderado', 'lejano'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['distancia'] == 'cercano']['puntaje_examen'],
    df[df['distancia'] == 'moderado']['puntaje_examen'],
    df[df['distancia'] == 'lejano']['puntaje_examen'],
)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 24.94
# Valor p: 1.6303083634793744e-11
#
# Conclusión: Hay diferencias significativas entre al menos dos tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['distancia'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2  meandiff p-adj  lower   upper  reject
# ------------------------------------------------------
# cercano   lejano  -1.0154   0.0  -1.407 -0.6237   True
# cercano moderado  -0.5272   0.0 -0.7822 -0.2722   True
#  lejano moderado   0.4882 0.017  0.0705  0.9059   True
# ------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# La siguiente variable a analizar es "Distancia", y se refiere a la distancia desde el hogar a la escuela. Con ANOVA se obtiene que sí existe una diferencia significativa, y con Tukey se logra comprender que, mientras más lejano es el hogar de los estudiantes, su promedio es más bajo. Esto se puede enlazar con la motivación, pues al tener que desplazarse en un trayecto largo, suelen presentarse fallas en la motivación.

# %% [markdown]
# **Género**

# %%
df['genero'].unique()
# Out:
# array(['hombre', 'mujer'], dtype=object)

# %%
# Si todos los grupos tienen una distribución normal
nivel_de_significancia = 0.05

# Realizar ANOVA
anova_result = stats.f_oneway(
    df[df['genero'] == 'hombre']['puntaje_examen'],
    df[df['genero'] == 'mujer']['puntaje_examen'],

)

# Interpretar los resultados
print("Resultados del ANOVA:")
print(f"F-Estadístico: {anova_result.statistic:.2f}")
print(f"Valor p: {anova_result.pvalue:}\n")

if anova_result.pvalue < nivel_de_significancia:
    print("Conclusión: Hay diferencias significativas entre al menos dos tratamientos.")
else:
    print("Conclusión: No hay diferencias significativas entre los tratamientos.")
# Out:
# Resultados del ANOVA:
# F-Estadístico: 0.16
# Valor p: 0.693695501200843
#
# Conclusión: No hay diferencias significativas entre los tratamientos.

# %%
nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['puntaje_examen'], groups=df['genero'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
# hombre  mujer   0.0391 0.6937 -0.1555 0.2337  False
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %% [markdown]
# La última variable a analizar es el género de los estudiantes. Después de someter esta variable a las pruebas ANOVA y Tukey, obtenemos como resultado que las diferencias no son significativas, es decir, la calificación no depende del género del alumno(a).

# %% [markdown]
# **Conclusión general**
#
# En el proyecto ya realizado pudimos crear un panorama mas amplio respecto a los factoreds que influyen en el nivel educativo de los estudiantes. Las pruebas ANOVA y Tukey fueron clave en el proceso ya que la primera prueba es de ayuda para saber si los grupos de las variables tienen diferencias significativas y de esta manera la prueba Tukey es la que nos dice cuáles son los grupos que tienen diferencias y nos muestra el gráfico, que nos ayuda a visualizar y entender mejor la información obtenida.
#
# Realizando todas estas pruebas se pudo observar que los factores cualitativos sí influyen en las calificaciones de los alumnos, lo cual es entendible ya que (por ejemplo) si tenemos un alumno que tiene un nivel de ingresos bajos y que por esta razón no tiene acceso a internet y  sus padres tienen que trabajar más y no están tan presentes es lógico que el alumno tenga bajas calificaciones.
#
# Es recomendable que se tome en cuenta todos los los factores ya analizados a la hora de etiquetar a un alumno como inteligente o ignorante.

# %% [markdown]
# **Bibliografía**
#
# Estadística, P. y. (2023, marzo 1). ▷ Análisis de la Varianza (ANOVA). Probabilidad y Estadística. https://www.probabilidadyestadistica.net/analisis-de-la-varianza-anova/
#
# Rendimiento Académico - Definición, Medidas Y Factores Que Influyen. (2023, enero 9). Organizadoresgraficos.org. https://www.organizadoresgraficos.org/rendimiento-academico/
